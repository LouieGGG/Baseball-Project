# %%
import pandas as pd

from pprint import pprint

from pybaseball import statcast as stc

# %%
stc
# Out:
# <function pybaseball.statcast.statcast(start_dt: str = None, end_dt: str = None, team: str = None, verbose: bool = True, parallel: bool = True) -> pandas.core.frame.DataFrame>

# %%
def baseball_stats(start_date, end_date):
  data = stc(start_dt = start_date,
             end_dt = end_date)
  return data

# %%
beginning_date = "2024-12-15"
ending_date = "2023-12-15"

# %%
stats = baseball_stats(beginning_date, ending_date)
# Out:
# This is a large query, it may take a moment to complete
# /opt/anaconda3/lib/python3.11/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# Skipping offseason dates
#   0%|          | 0/246 [00:00<?, ?it/s]
# ...

# %%
sum_stats = stats.drop(['release_pos_x',
 'release_pos_z',
 'batter',
 'pitcher',
 'spin_dir',
 'spin_rate_deprecated',
 'break_angle_deprecated',
 'break_length_deprecated',
 'type',
 'hit_location',
 'bb_type',
 'pfx_x',
 'pfx_z',
 'plate_x',
 'plate_z',
 'on_3b',
 'on_2b',
 'on_1b',
 'hc_x',
 'hc_y',
 'tfs_deprecated',
 'tfs_zulu_deprecated',
 'umpire',
 'sv_id',
 'vx0',
 'vy0',
 'vz0',
 'ax',
 'ay',
 'az',
 'sz_top',
 'sz_bot',
 'hit_distance_sc',
 'launch_speed',
 'launch_angle',
 'game_pk',
 'fielder_2',
 'fielder_3',
 'fielder_4',
 'fielder_5',
 'fielder_6',
 'fielder_7',
 'fielder_8',
 'fielder_9',
 'estimated_ba_using_speedangle',
 'estimated_woba_using_speedangle',
 'woba_value',
 'woba_denom',
 'babip_value',
 'iso_value',
 'launch_speed_angle',
 'at_bat_number',
 'pitch_name',
 'home_score',
 'away_score',
 'fld_score',
 'post_away_score',
 'post_home_score',
 'post_bat_score',
 'post_fld_score',
 'spin_axis',
 'delta_home_win_exp',
 'delta_run_exp',
 'bat_speed',
 'swing_length',
 'estimated_slg_using_speedangle',
 'delta_pitcher_run_exp',
 'hyper_speed',
 'home_score_diff',
 'bat_score_diff',
 'home_win_exp',
 'bat_win_exp',
 'age_pit_legacy',
 'age_bat_legacy',
 'age_pit',
 'age_bat',
 'n_thruorder_pitcher',
 'n_priorpa_thisgame_player_at_bat',
 'pitcher_days_since_prev_game',
 'batter_days_since_prev_game',
 'pitcher_days_until_next_game',
 'batter_days_until_next_game',
 'api_break_z_with_gravity',
 'api_break_x_arm',
 'api_break_x_batter_in',
 'inning_topbot',
 'release_spin_rate',
 'release_extension',
 'release_pos_y',
 'des',
 'description',
 'outs_when_up',
 'spin_dir',
 'spin_rate_deprecated',
  'break_angle_deprecated',
  'break_length_deprecated',
  'p_throws',
  'events',
  'zone'
 ], axis=1)

# %%
sum_stats
# Out:
#      pitch_type  game_date  release_speed      player_name game_type stand  \
# 162          KC 2024-10-30           77.5  Buehler, Walker         W     L
# 176          KC 2024-10-30           78.7  Buehler, Walker         W     L
# 178          FC 2024-10-30           93.1  Buehler, Walker         W     L
# 191          KC 2024-10-30           78.5  Buehler, Walker         W     L
# 203          KC 2024-10-30           77.4  Buehler, Walker         W     L
# ...         ...        ...            ...              ...       ...   ...
# 1688        NaN 2024-03-15           <NA>    Singer, Brady         S     L
# 1822        NaN 2024-03-15           <NA>    Singer, Brady         S     L
# 1879        NaN 2024-03-15           <NA>    Singer, Brady         S     L
# 1973        NaN 2024-03-15           <NA>    Singer, Brady         S     L
# 2048        NaN 2024-03-15           <NA>    Singer, Brady         S     L
#
# ...

# %%
sum_stats.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'player_name', 'events',
#        'zone', 'game_type', 'stand', 'home_team', 'away_team', 'balls',
#        'strikes', 'game_year', 'inning', 'effective_speed', 'pitch_number',
#        'bat_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'arm_angle'],
#       dtype='object')

# %% [markdown]
# # Check if there are NaNs in sum_stats

# %%
sum_stats['pitch_type'].isna().sum()/len(sum_stats)*100
# Out:
# 1.806224784318073

# %%
sum_stats['release_speed'].isna().sum()/len(sum_stats)*100
# Out:
# 1.9649920220452861

# %%
sum_stats['effective_speed'].isna().sum()/len(sum_stats)*100
# Out:
# 2.114652909478919

# %%
sum_stats['of_fielding_alignment'].isna().sum()/len(sum_stats)*100
# Out:
# 2.882357832055145

# %%
sum_stats['arm_angle'].isna().sum()/len(sum_stats)*100
# Out:
# 5.089130053199562

# %% [markdown]
# ## Limpieza de NaNs

# %%
sum_stats['pitch_type'] = sum_stats['pitch_type'].fillna('Unknown')
sum_stats['pitch_type'] = sum_stats['pitch_type'].fillna('Unknown')
